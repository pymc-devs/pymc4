# %%
# %load_ext autoreload
# %autoreload 2
import pymc4 as pm
import numpy as np
from pymc4.mcmc.samplers import RandomWalkM

# %%
@pm.model
def model():
    mu = yield pm.Normal("mu1", 0, 1.)
    mu = yield pm.Normal("mu2", 0, 1.)
    mu = yield pm.Normal("mu3", 0, 1.)
    return mu

# %%
trace = pm.sample(model(), sampler_type="compound", sampler_methods=[("mu1", RandomWalkM), ("qmu3", RandomWalkM)])
# Out:
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# one_step
# ...

# %%
import arviz as az
az.plot_trace(trace)
