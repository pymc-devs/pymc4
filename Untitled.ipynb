# %%
# %load_ext autoreload
# %autoreload 2
import pymc4 as pm
import arviz as az

# %%
@pm.model
def bernoulli():
    var1 = yield pm.Normal("var1", 0, 1)

# %%
trace = pm.sample(bernoulli(), sampler_type="compound") 
# after the review default attribute should be compound and if there is no
# discrete variable in the model, we choose nuts as the sampler
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# I0731 06:17:06.237898 140582701524800 samplers.py:460] Auto-assigning NUTS sampler...

# %%
import pymc3 as pm

# %%
with pm.Model() as model:
    mu = pm.Bernoulli("mu", 0.5)
    mu2 = pm.Normal("mu2", 0., 1.)
    tr = pm.sample()
# Out:
# Sampling 2 chains, 0 divergences: 100%|██████████| 2000/2000 [00:01<00:00, 1914.23draws/s]

# %%
az.plot_trace(tr)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fdb2b983f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdb2b887be0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fdb2b8b8c18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdb2b86dc50>]],
#       dtype=object)

# %%
sets = {1}

# %%
sets.add({1:2})
sets.add({1:2})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-b818f349b40c> in <module>
# ----> 1 sets.add({1:2})
#
# TypeError: unhashable type: 'dict'
