# %%
import pymc4 as pm
import numpy as np
import arviz as az

# %% [markdown]
# Let's test the performance on the eight school model:

# %%
# define parametrization
J = 8
y = np.array([28,  8, -3,  7, -1,  1, 18, 12], dtype=np.float32)
sigma = np.array([15, 10, 16, 11,  9, 11, 10, 18], dtype=np.float32)

# %%
# define the model
@pm.model
def schools_pm4():
    eta = yield pm.Normal("eta", 0, 1, batch_stack=J)
    mu = yield pm.Normal("mu", 0, 1, batch_stack=1)
    tau = yield pm.HalfNormal('tau', 2., batch_stack=1)
    
    theta = mu + tau * eta

    obs = yield pm.Normal('obs', theta, scale=sigma, observed=y)

    return obs

# %%
def collect_performance_stat():

# %%
#%%timeit
pm.sample(schools_pm4(), progressbar=True)
# Out:
# 100%|██████████| 1000/1000 [00:31<00:00, 31.27it/s]
# Inference data with groups:
# 	> posterior
# 	> sample_stats
# 	> observed_data

# %%
az.plot_trace(trace);
