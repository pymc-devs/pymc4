# %%
# %load_ext autoreload
# %autoreload 2
import pymc4 as pm

# %%
@pm.model
def model():
    m1 = yield pm.Normal("m1", 0, 1)
    m2 = yield pm.Normal("m2", 1, 1)

# %%
pm.sample(model(), sampler_type="compound")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-ac726ee1c02e> in <module>
# ----> 1 pm.sample(model(), sampler_type="compound")
#
# /home/rasul/Desktop/forks/final/pymc4/pymc4/inference/sampling.py in sample(model, sampler_type, num_samples, num_chains, burn_in, observed, state, xla, use_auto_batching, custom_trace_fn, **kwargs)
#     125         state=state,
#     126         use_auto_batching=use_auto_batching,
# --> 127         xla=xla,
#     128     )
#     129
#
# /home/rasul/Desktop/forks/final/pymc4/pymc4/mcmc/samplers.py in __call__(self, *args, **kwargs)
#     170
#     171     def __call__(self, *args, **kwargs):
# --> 172         return self.sample(*args, **kwargs)
#     173
#     174     def _bound_kwargs(self, *args):
#
# ...

# %%
pm.mcmc.samplers.CompoundStep._default_kernel_maker()
# Out:
# KERNEL_ARGS_SET(kernel=<class 'pymc4.mcmc.tf_support._CompoundStepTF'>, adaptive_kernel=None, kernel_kwargs={}, adaptive_kwargs={})
