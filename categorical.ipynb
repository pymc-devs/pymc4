# %%
# Categorical sampling

# %%
# %load_ext autoreload
# %autoreload 2
import pymc4 as pm

# %%
@pm.model
def model():
    var = yield pm.Categorical("var", [0.1, 0.9])
    mean = yield pm.Normal("mean", 0, 1)

# %%
trace = pm.sample(model(), sampler_type="compound")
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# E0310 00:39:48.239587 140674108585792 pfor.py:1475] Got error while pfor was converting op name: "mcmc_sample_chain/compound_bootstrap_results/loop_body/StatefulPartitionedCall"
# op: "StatefulPartitionedCall"
# input: "mcmc_sample_chain/compound_bootstrap_results/loop_body/GatherV2"
# input: "mcmc_sample_chain/compound_bootstrap_results/loop_body/GatherV2_1"
# attr {
#   key: "Tin"
#   value {
#     list {
#       type: DT_FLOAT
#       type: DT_FLOAT
#     }
#   }
# }
# attr {
#   key: "Tout"
#   value {
#     list {
#       type: DT_FLOAT
#     }
#   }
# }
# attr {
#   key: "_gradient_op_type"
#   value {
#     s: "PartitionedCallUnused"
#   }
# }
# attr {
#   key: "config"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "config_proto"
#   value {
#     s: "\n\007\n\003CPU\020\001\n\007\n\003GPU\020\0002\002J\0008\001"
#   }
# }
# attr {
#   key: "executor_type"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "f"
# ...

# %%
import arviz as az

# %%
az.plot_posterior(trace, var_names="model/var");
